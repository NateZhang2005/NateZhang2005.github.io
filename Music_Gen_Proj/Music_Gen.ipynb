# %% [markdown]
# # 1. Problem Statement

# %% [markdown]
# To start, our project sought to utilize musical features (such as tempo, key signature, and note density) to create a machine learning model that is able to accurate generate new MIDI music.
#
# Thus, our problem statement is: Given the distribution of defining musical features (such as tempo, key signature, and note density) within music, how are we able to craft a machine-learning model that accurately generates new MIDI music?
#
# We decided to use the Lakh dataset (https://colinraffel.com/projects/lmd/) because it had a wider range of musical genres and artists the model could train on compared to the Maestro dataset.
#
# Based on our thorough exploration of the data, with more information on this below, our revised project question remains generally consistent. However, as our training datasets are primarily encompassed with $\texttt{pop}$ genre music, we seek to answer said question, but in the context of $\texttt{pop}$ .

# %% [markdown]
# ## Imports

# %%
# install packages
# %pip install pretty_midi librosa tables music21
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pretty_midi in ./.local/lib/python3.11/site-packages (0.2.10)
# Requirement already satisfied: librosa in ./.local/lib/python3.11/site-packages (0.11.0)
# Requirement already satisfied: tables in ./.local/lib/python3.11/site-packages (3.10.2)
# Requirement already satisfied: music21 in ./.local/lib/python3.11/site-packages (9.5.0)
# Requirement already satisfied: numpy>=1.7.0 in ./.local/lib/python3.11/site-packages (from pretty_midi) (1.26.4)
# Requirement already satisfied: mido>=1.1.16 in ./.local/lib/python3.11/site-packages (from pretty_midi) (1.3.3)
# Requirement already satisfied: six in ./.local/lib/python3.11/site-packages (from pretty_midi) (1.17.0)
# Requirement already satisfied: audioread>=2.1.9 in ./.local/lib/python3.11/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in ./.local/lib/python3.11/site-packages (from librosa) (0.61.2)
# Requirement already satisfied: scipy>=1.6.0 in /shared/courseSharedFolders/142601outer/142601/cs109b/lib/python3.11/site-packages (from librosa) (1.12.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /shared/courseSharedFolders/142601outer/142601/cs109b/lib/python3.11/site-packages (from librosa) (1.4.0)
# Requirement already satisfied: joblib>=1.0 in /shared/courseSharedFolders/142601outer/142601/cs109b/lib/python3.11/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /shared/courseSharedFolders/142601outer/142601/cs109b/lib/python3.11/site-packages (from librosa) (5.2.1)
# Requirement already satisfied: soundfile>=0.12.1 in ./.local/lib/python3.11/site-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in ./.local/lib/python3.11/site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in ./.local/lib/python3.11/site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in ./.local/lib/python3.11/site-packages (from librosa) (4.13.2)
# Requirement already satisfied: lazy_loader>=0.1 in ./.local/lib/python3.11/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in ./.local/lib/python3.11/site-packages (from librosa) (1.1.0)
# Requirement already satisfied: numexpr>=2.6.2 in ./.local/lib/python3.11/site-packages (from tables) (2.10.2)
# Requirement already satisfied: packaging in ./.local/lib/python3.11/site-packages (from tables) (25.0)
# Requirement already satisfied: py-cpuinfo in ./.local/lib/python3.11/site-packages (from tables) (9.0.0)
# Requirement already satisfied: blosc2>=2.3.0 in ./.local/lib/python3.11/site-packages (from tables) (3.3.1)
# Requirement already satisfied: chardet in ./.local/lib/python3.11/site-packages (from music21) (5.2.0)
# Requirement already satisfied: jsonpickle in ./.local/lib/python3.11/site-packages (from music21) (4.0.5)
# Requirement already satisfied: matplotlib in /shared/courseSharedFolders/142601outer/142601/cs109b/lib/python3.11/site-packages (from music21) (3.8.2)
# Requirement already satisfied: more-itertools in ./.local/lib/python3.11/site-packages (from music21) (10.7.0)
# Requirement already satisfied: requests in ./.local/lib/python3.11/site-packages (from music21) (2.32.3)
# Requirement already satisfied: webcolors>=1.5 in /shared/courseSharedFolders/142601outer/142601/cs109b/lib/python3.11/site-packages (from music21) (24.11.1)
# Requirement already satisfied: ndindex in ./.local/lib/python3.11/site-packages (from blosc2>=2.3.0->tables) (1.9.2)
# Requirement already satisfied: platformdirs in /shared/courseSharedFolders/142601outer/142601/cs109b/lib/python3.11/site-packages (from blosc2>=2.3.0->tables) (4.3.6)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in ./.local/lib/python3.11/site-packages (from numba>=0.51.0->librosa) (0.44.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.local/lib/python3.11/site-packages (from requests->music21) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.local/lib/python3.11/site-packages (from requests->music21) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.local/lib/python3.11/site-packages (from requests->music21) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.local/lib/python3.11/site-packages (from requests->music21) (2025.4.26)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared/courseSharedFolders/142601outer/142601/cs109b/lib/python3.11/site-packages (from scikit-learn>=1.1.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /shared/courseSharedFolders/142601outer/142601/cs109b/lib/python3.11/site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in /shared/courseSharedFolders/142601outer/142601/cs109b/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: contourpy>=1.0.1 in /shared/courseSharedFolders/142601outer/142601/cs109b/lib/python3.11/site-packages (from matplotlib->music21) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /shared/courseSharedFolders/142601outer/142601/cs109b/lib/python3.11/site-packages (from matplotlib->music21) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /shared/courseSharedFolders/142601outer/142601/cs109b/lib/python3.11/site-packages (from matplotlib->music21) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /shared/courseSharedFolders/142601outer/142601/cs109b/lib/python3.11/site-packages (from matplotlib->music21) (1.4.7)
# Requirement already satisfied: pillow>=8 in /shared/courseSharedFolders/142601outer/142601/cs109b/lib/python3.11/site-packages (from matplotlib->music21) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /shared/courseSharedFolders/142601outer/142601/cs109b/lib/python3.11/site-packages (from matplotlib->music21) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./.local/lib/python3.11/site-packages (from matplotlib->music21) (2.9.0.post0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import tables
import IPython.display
import os
import json
import tarfile
import random 
import tensorflow as tf
from tensorflow import keras
from keras.models import Model, Sequential, load_model
from keras import layers
from keras import losses
from keras import optimizers
from keras.callbacks import EarlyStopping, LambdaCallback, ModelCheckpoint
from keras.layers import Input, Embedding, SimpleRNN, GRU, LSTM, TimeDistributed, Bidirectional, Dense, RNN
from keras.layers import  BatchNormalization, Activation, Dropout, GaussianNoise
from keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.python.keras import backend as K
from sklearn.model_selection import train_test_split
import pretty_midi
import librosa
from music21 import converter, note, chord
from concurrent.futures import ProcessPoolExecutor, as_completed
from tqdm import tqdm
import os
from collections import Counter
# from google.colab import drive
# Out:
# 2025-05-09 13:46:39.654093: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-09 13:46:39.654152: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-09 13:46:39.654931: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-09 13:46:39.661399: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Above we have a series of imports that we will be utilzing for this project. In addition to this, we print the size of our dataset in order to understand the weight of our selected dataset. We ultimately find the dataset to be a hefty one, with 17,256 MIDI files (each file representative of a data entry).

# %%
# Mount google drive
# drive.mount('/content/drive')

# Open TAR file data from the cleaned dataset
tar = tarfile.open('data/clean_midi.tar')

# Collect file names
file_names = np.array(tar.getnames()[1:])
mask = ['.mid' in x for x in file_names]
indices = np.where(mask)[0]
file_names = file_names[indices]

# Print number of MIDIs in dataset
print(f'There are {len(file_names)} MIDI files in the cleaned dataset.')
print(file_names)
# Out:
# There are 17256 MIDI files in the cleaned dataset.
# ['clean_midi/Hugues Aufray/Celine.mid'
#  'clean_midi/Linda Ronstadt/When Will I Be Loved.mid'
#  "clean_midi/Linda Ronstadt/You're No Good.mid" ...
#  'clean_midi/Haddaway/What Is Love.mid'
#  'clean_midi/Haddaway/What Is Love.4.mid'
#  "clean_midi/Alpenrebellen/Die Leut' am Land.mid"]

# %%
# Extraction folder path
extract_path = "extracted_midi"

# Check if folder exists
if not os.path.exists(extract_path):
    print("Extracting MIDI files with folder structure preserved...")

    os.makedirs(extract_path, exist_ok=True)

    with tarfile.open("data/clean_midi.tar", "r") as tar:
        # Only include MIDI files
        midi_members = [m for m in tar.getmembers() if m.name.endswith(".mid")]
        
        # Extract with folder structure
        tar.extractall(path=extract_path, members=midi_members)
    print(f"Extraction complete. {len(midi_members)} MIDI files saved to '{extract_path}'.")

else:
    print(f"Folder '{extract_path}' already exists. Skipping extraction.")
# Out:
# Folder 'extracted_midi' already exists. Skipping extraction.

# %% [markdown]
# Above, we simply extract our dataset, while maintaining its given folder structure.

# %% [markdown]
# # 2. Exploratory Data Analysis

# %%
# Updated path to where it's now stored
file_path = "extracted_midi/clean_midi/Haddaway/What Is Love.mid"

# Use converter to find key
midi_file = converter.parse(file_path)
key = midi_file.analyze('key')
print(f"Key: {key}")
# Out:
# Key: B major

# %% [markdown]
# We use the $\texttt{Music21}$ to find the corresponding musical key for each song in the $\texttt{Cleaned Lakh Dataset}$.

# %%
# Match each MIDI file to its corresponding genre
genres_df = pd.read_csv('data/genre.tsv', sep='\t')
incorrect_cols = genres_df.columns # read_csv makes the first row of the tsv file as the column of the dataframe
genres_df = genres_df.rename(columns={incorrect_cols[0]:'filename', incorrect_cols[1]: 'genre'})

# Append the incorrect columns into the dataframe
genres_df.loc[len(genres_df)] = incorrect_cols
display(genres_df.head())

# Create histogram charting frequency of the top most frequent genres in dataset
genres_df['genre'].value_counts().head(20).plot(kind='bar')
plt.title('Top 20 Genres - Lakh MIDI Dataset')
plt.show()
# Out:
#                                filename             genre
# 0        10,000 Maniacs/A Campfire Song  Alternative rock
# 1  101 Strings/Theme From The Godfather               Pop
# 2                10cc/Dreadlock Holiday       Reggae rock
# 3                  10cc/I'm Not In Love         Soft rock
# 4        10cc/The Things We Do for Love         Soft rock

# %% [markdown]
# We utilize the $\texttt{Genres Dataset}$, a genre-matched subset of data from the cleaned Lakh dataset. The analysis from the plot above shows that our dataset primarily contains $\texttt{Pop}$ music, with almost 2000 songs being categorized as said genre. There are approximately 800 songs in the genre of $\texttt{Rock}$, 500 songs in $\texttt{Pop rock}$, 450 songs in $\texttt{Alternative/Indie}$ and 300 songs in $\texttt{Jazz}$.

# %%
# Function to extract time signature, tempo, and the number of notes from MIDI
def extract_meta_data(file_name):
    file_path = os.path.join("extracted_midi", file_name)

    try:
        midi_data = pretty_midi.PrettyMIDI(file_path)

        # Get time signature
        if midi_data.time_signature_changes:
            ts = midi_data.time_signature_changes[0]
            time_signature = f"{ts.numerator}/{ts.denominator}"
        else:
            time_signature = None

        # Calculate tempo (halve value to correctly estimated – double-time issue)
        tempo = midi_data.estimate_tempo() / 2

        # Calculate total number of notes
        num_notes = sum(len(inst.notes) for inst in midi_data.instruments)

        # Find key signatures are completely optional meta-event – many MIDI files don't have this information
        if midi_data.key_signature_changes:
            key_signature = midi_data.key_signature_changes[0].key_number
        else:
            key_signature = None

        # Get duration
        if midi_data.get_end_time():
            duration = midi_data.get_end_time()
        else:
            duration = None
        
        return time_signature, tempo, key_signature, num_notes, duration

    except Exception as e:
        return None, None, None, None, None

# Arrays to store the found
time_signatures = []
tempos = []
key_signatures = []
num_notes = []
song_duration = []

# Set seed and also shuffle the data
random.seed(109)
shuffled_file_names = np.random.permutation(file_names)

for file_name in shuffled_file_names[:1000]:
  time, tempo, key, notes, duration = extract_meta_data(file_name)
  time_signatures.append(time)
  tempos.append(tempo)
  key_signatures.append(key)
  num_notes.append(notes)
  song_duration.append(duration)

# Remove entries with for each list
key_signatures = [key for key in key_signatures if key is not None]
time_signatures = [time for time in time_signatures if time is not None]
tempos = [tempo for tempo in tempos if tempo is not None]
num_notes = [note for note in num_notes if note is not None]
song_duration = [dur for dur in song_duration if dur is not None]

print('Extraction of meta-data complete')
# Out:
# /shared/home/dap6224/.local/lib/python3.11/site-packages/pretty_midi/pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Extraction of meta-data complete

# %%
# Plot histogram of time signatures
plt.hist(time_signatures, bins=20, color='lightblue')
plt.title('Distribution of Time Signatures')
plt.xlabel('Time Signature')
plt.ylabel('Frequency')
plt.show()

# Plot distribution of tempos
plt.hist(tempos, bins=50, color='lightblue')
plt.title('Distribution of Tempos')
plt.xlabel('Tempo')
plt.ylabel('Frequency')
plt.show()

# Plot distribution of notes
plt.hist(num_notes, bins=50, color='lightblue')
plt.title('Distribution of Number of Notes')
plt.xlabel('Number of Notes')
plt.ylabel('Frequency')
plt.show()

# Plot distribution of duration
plt.hist(song_duration, bins=50, color='lightblue')
plt.title('Distribution of Song Durations')
plt.xlabel('Duration (s)')
plt.ylabel('Frequency')
plt.show()

# Plot distribution of key signatures

# Mapping from key_number to musical key name
key_number_to_name = {
    0: "C Major",   1: "C# Major",  2: "D Major",   3: "D# Major",
    4: "E Major",   5: "F Major",   6: "F# Major",  7: "G Major",
    8: "G# Major",  9: "A Major",  10: "A# Major", 11: "B Major",
    12: "C Minor", 13: "C# Minor", 14: "D Minor", 15: "D# Minor",
    16: "E Minor", 17: "F Minor", 18: "F# Minor", 19: "G Minor",
    20: "G# Minor",21: "A Minor", 22: "A# Minor", 23: "B Minor"
}

# Convert numeric keys to musical names using the dictionary
key_names = [key_number_to_name[k] for k in key_signatures if k in key_number_to_name]

# Plot as categorical histogram
plt.figure(figsize=(12, 5))
plt.hist(key_names, bins=len(set(key_names)), color='lightblue')
plt.title('Distribution of Key Signatures')
plt.xlabel('Key Signature')
plt.xticks(rotation=90)
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Function to filter data - only C Major/A Minor, 4/4 Time, 90-120 BPM
def filter_midi_files(folder_path):
    filtered_files = []

    # Find files that are relevant
    for filename in folder_path:
        # print(filename)
        if filename.endswith(".mid") or filename.endswith(".midi"):
            filepath = os.path.join('extracted_midi', filename)
            
            try:
                midi_data = pretty_midi.PrettyMIDI(filepath)

                # Check time signature
                time_signatures = midi_data.time_signature_changes
                if time_signatures:
                    # Check if time_signature is 4/4
                    ts = time_signatures[0]
                    if ts.numerator != 4 or ts.denominator != 4:
                        continue
                else:
                    continue

                # Check key signature
                key_signatures = midi_data.key_signature_changes
                if key_signatures:
                    # 0 = C major (in pretty_midi key mapping)
                    key = key_signatures[0].key_number
                    if key != 0 and key != 9:
                        continue
                else:
                    continue

                # Check tempo
                tempo_changes = midi_data.get_tempo_changes()
                tempos = tempo_changes[1]  # tempo values
                if tempos.size > 0:
                    avg_tempo = tempos.mean()
                    if not (90 <= avg_tempo <= 120):
                        continue
                else:
                    continue

                # If all conditions pass, keep the midi file
                filtered_files.append(filepath)

            except Exception as e:
                print(f"Error reading {filename}: {e}")
    
    return filtered_files

# Example usage
filtered_songs = filter_midi_files(file_names)
print(f"Found {len(filtered_songs)} good songs.")
# Out:
# Error reading clean_midi/Cabrel Francis/Encore et encore.mid: Could not decode key with 4 flats and mode 255
# Error reading clean_midi/Cabrel Francis/Question d'equilibre.mid: Could not decode key with 4 flats and mode 255
# Error reading clean_midi/The Beach Boys/I Get Around.2.mid: data byte must be in range 0..127
# Error reading clean_midi/The Beach Boys/Good Vibrations.6.mid: data byte must be in range 0..127
# Error reading clean_midi/Frank Sinatra/Summer Wind.mid: data byte must be in range 0..127
# Error reading clean_midi/Us3/Cantaloop.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Boyz II Men/End of the Road.2.mid: data byte must be in range 0..127
# Error reading clean_midi/Simon & Garfunkel/The Sound of Silence.2.mid: MIDI file has a largest tick of 25433089, it is likely corrupt
# Error reading clean_midi/Peter Gabriel/Solsbury Hill.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Peter Gabriel/Solsbury Hill.mid: data byte must be in range 0..127
# Error reading clean_midi/Miller/When Sunny Gets Blue.mid: data byte must be in range 0..127
# Error reading clean_midi/Alison Moyet/All Cried Out.mid: data byte must be in range 0..127
# Error reading clean_midi/Journey/Any Way You Want It.mid: data byte must be in range 0..127
# Error reading clean_midi/Journey/Lights.mid: data byte must be in range 0..127
# Error reading clean_midi/Journey/Lovin' Touchin' Squeezin'.mid: data byte must be in range 0..127
# Error reading clean_midi/Jovanotti/Penso Positivo.mid: data byte must be in range 0..127
# Error reading clean_midi/Bush/Glycerine.1.mid: Could not decode key with 1 flats and mode 255
# Error reading clean_midi/Marley Bob/Iron Lion Zion.mid: data byte must be in range 0..127
# Error reading clean_midi/Busta Rhymes/Woo Hah.mid: data byte must be in range 0..127
# Error reading clean_midi/Last/Rosamunde.1.mid: MIDI file has a largest tick of 12027564, it is likely corrupt
# Error reading clean_midi/Nick Kamen/I Promised Myself.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Commodores/Three Times a Lady.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Cocciante/Ammassati e distanti.mid: data byte must be in range 0..127
# Error reading clean_midi/Basie/I Left My Heart in San Francisco.mid: data byte must be in range 0..127
# Error reading clean_midi/Shirley Bassey/Big Spender.mid: data byte must be in range 0..127
# Error reading clean_midi/Nek/Se io non avessi te.2.mid: data byte must be in range 0..127
# Error reading clean_midi/Yanni/Marching Season.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Yanni/Aria.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Yanni/Secret Vows.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Yanni/Swept Away.mid: running status without last_status
# Error reading clean_midi/Yanni/The Rain Must Fall.1.mid: data byte must be in range 0..127
# Error reading clean_midi/McDonald/Yah Mo B There.mid: data byte must be in range 0..127
# Error reading clean_midi/TURNER TINA/Notbush City Limits.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Lenny Kravitz/I Belong To You.mid: data byte must be in range 0..127
# Error reading clean_midi/Aerosmith/Pink.3.mid:
# Error reading clean_midi/Aerosmith/Dream On.mid: data byte must be in range 0..127
# Error reading clean_midi/Whitney Houston/Saving All My Love For You.2.mid: data byte must be in range 0..127
# Error reading clean_midi/Whitney Houston/I'm Every Woman.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Los Del Rio/Macarena.1.mid: Message length 2093056 exceeds maximum length 1000000
# Error reading clean_midi/Radiohead/Karma Police.mid: data byte must be in range 0..127
# Error reading clean_midi/Radiohead/Airbag.mid: data byte must be in range 0..127
# Error reading clean_midi/Radiohead/Subterranean Homesick Alien.mid: data byte must be in range 0..127
# Error reading clean_midi/Radiohead/Climbing Up the Walls.mid: data byte must be in range 0..127
# Error reading clean_midi/Buddy Holly/Peggy Sue.1.mid:
# Error reading clean_midi/Miami Sound Machine/Here We Are.mid: data byte must be in range 0..127
# Error reading clean_midi/The Prodigy/Wind It Up.mid: data byte must be in range 0..127
# Error reading clean_midi/The Prodigy/Climbatize.mid: data byte must be in range 0..127
# Error reading clean_midi/Ross/When You Tell Me That You Love Me.mid: data byte must be in range 0..127
# Error reading clean_midi/Amedeo Minghi/Decenni.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Henry Arland/Rosenmelodie.mid: data byte must be in range 0..127
# Error reading clean_midi/Jethro Tull/Rainbow Blues.mid: Could not decode key with 2 flats and mode 255
# Error reading clean_midi/Rene Carol/Rote Rosen rote Lippen roter Wein.mid: data byte must be in range 0..127
# Error reading clean_midi/Billy Joel/Movin' Out (Anthony's Song).mid: data byte must be in range 0..127
# Error reading clean_midi/Billy Joel/Pressure.2.mid: data byte must be in range 0..127
# Error reading clean_midi/Billy Joel/Pressure.mid: data byte must be in range 0..127
# Error reading clean_midi/Tom Jones/Delilah.5.mid: data byte must be in range 0..127
# Error reading clean_midi/Phish/Taste.mid: MThd not found. Probably not a MIDI file
# Error reading clean_midi/Jennifer Lopez/If You Had My Love.mid: MThd not found. Probably not a MIDI file
# Error reading clean_midi/Kylie Minogue/Especially for You.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Kylie Minogue/Better the Devil.mid: data byte must be in range 0..127
# Error reading clean_midi/Crow Sheryl/Tomorrow Never Dies.mid: data byte must be in range 0..127
# Error reading clean_midi/Earth, Wind & Fire/September (bonus track).4.mid: data byte must be in range 0..127
# Error reading clean_midi/Andre Hazes/Ik meen 't.2.mid: data byte must be in range 0..127
# Error reading clean_midi/Right Said Fred/Don't Talk Just Kiss.mid: data byte must be in range 0..127
# Error reading clean_midi/UB40/Homely Girl.mid: data byte must be in range 0..127
# Error reading clean_midi/Vangelis/Chariots of Fire.5.mid: data byte must be in range 0..127
# Error reading clean_midi/Los Lobos/La Bamba.mid: Could not decode key with 2 flats and mode 255
# Error reading clean_midi/Van Halen/Me Wise Magic.mid:
# Error reading clean_midi/Van Halen/Jump.5.mid: data byte must be in range 0..127
# Error reading clean_midi/Van Halen/Right Now.1.mid: data byte must be in range 0..127
# Error reading clean_midi/The KLF/Justified and Ancient.1.mid: data byte must be in range 0..127
# Error reading clean_midi/The Boomtown Rats/I Don't Like Monday's.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Rednex/The Ultimate Rednex Mega Mix, Part 3: Cotton Eye Joe.mid: data byte must be in range 0..127
# Error reading clean_midi/Genesis/Misunderstanding.3.mid: data byte must be in range 0..127
# Error reading clean_midi/Genesis/Abacab.3.mid:
# Error reading clean_midi/Metallica/The Unforgiven.3.mid:
# Error reading clean_midi/Metallica/The Shortest Straw.1.mid:
# Error reading clean_midi/Metallica/The Unforgiven.5.mid: data byte must be in range 0..127
# Error reading clean_midi/Metallica/(Anesthesia)-Pulling Teeth.mid:
# Error reading clean_midi/Gompie/Alice (Who the X Is Alice) (Living Next Door to Alice).mid: data byte must be in range 0..127
# Error reading clean_midi/Andre Brasseur/Early Bird Satellite.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Bruce Springsteen/Tenth Avenue Freeze-Out.1.mid: MIDI file has a largest tick of 33639950, it is likely corrupt
# Error reading clean_midi/Stan Kenton/Here's That Rainy Day.mid: data byte must be in range 0..127
# Error reading clean_midi/Sarah McLachlan/Adia.1.mid:
# Error reading clean_midi/John Paul Young/Love is in the Air.3.mid: data byte must be in range 0..127
# Error reading clean_midi/Eric Clapton/Tears in Heaven.7.mid: data byte must be in range 0..127
# Error reading clean_midi/Scott McKenzie/Forrest Gump: San Francisco (Be Sure to Wear Some Flowers in Your Hair).1.mid: data byte must be in range 0..127
# Error reading clean_midi/The Alan Parsons Project/Sirius   Eye in the Sky.mid: Could not decode key with 2 flats and mode 163
# Error reading clean_midi/Celine Dion/Where Does My Heart Beat Now.1.mid: Could not decode key with 2 flats and mode 255
# Error reading clean_midi/Celine Dion/Where Does My Heart Beat Now.mid: Could not decode key with 2 flats and mode 255
# Error reading clean_midi/Celine Dion/That's The Way It Is.mid: data byte must be in range 0..127
# Error reading clean_midi/Barry Manilow/Copa Cabana (disco).mid: data byte must be in range 0..127
# Error reading clean_midi/Juan Luis Guerra/La Bilirrubina.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Dee/The Legend Of Xanadu.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Eurythmics/Who's That Girl.mid: Could not decode key with 5 flats and mode 255
# Error reading clean_midi/Eurythmics/Sweet Dreams.4.mid: Could not decode key with 3 flats and mode 255
# Error reading clean_midi/Nini Rosso/Il Silenzio.1.mid: Could not decode key with 14 sharps and mode 78
# Error reading clean_midi/Asia/Don't Cry.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Rob Zombie/Demonoid Phenomenon.mid: MIDI file has a largest tick of 4295115785, it is likely corrupt
# Error reading clean_midi/Dan Fogelberg/Leader Of The Band.mid: Could not decode key with 4 flats and mode 255
# Error reading clean_midi/Clayderman Richard/Ballade Pour Adeline.mid: data byte must be in range 0..127
# Error reading clean_midi/Cream/Strange Brew.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Roxette/It Must Have Been Love (live studio).3.mid: MIDI file has a largest tick of 4295053573, it is likely corrupt
# Error reading clean_midi/Roxette/The Look.mid: data byte must be in range 0..127
# Error reading clean_midi/The Beatles/Octopus's Garden.mid: data byte must be in range 0..127
# Error reading clean_midi/The Beatles/Fool on the Hill.2.mid: data byte must be in range 0..127
# Error reading clean_midi/The Beatles/Get Back.3.mid: data byte must be in range 0..127
# Error reading clean_midi/The Beatles/Ticket to Ride.6.mid: data byte must be in range 0..127
# Error reading clean_midi/The Beatles/Fool on the Hill.mid: data byte must be in range 0..127
# Error reading clean_midi/The Beatles/Every Little Thing.mid: data byte must be in range 0..127
# Error reading clean_midi/The Beatles/Let It Be.5.mid: data byte must be in range 0..127
# Error reading clean_midi/The Beatles/Paperback Writer.4.mid: data byte must be in range 0..127
# Error reading clean_midi/The Beatles/All You Need Is Love.3.mid: data byte must be in range 0..127
# Error reading clean_midi/The Beatles/Fixing a Hole.mid: data byte must be in range 0..127
# Error reading clean_midi/Jamiroquai/Canned Heat.1.mid:
# Error reading clean_midi/Rush/Closer to the Heart.3.mid: data byte must be in range 0..127
# Error reading clean_midi/Rush/Broon's Bane.1.mid: Could not decode key with 1 flats and mode 255
# Error reading clean_midi/Rush/Leave That Thing Alone.mid: data byte must be in range 0..127
# Error reading clean_midi/Gina G/Ooh Ahh Just a Little Bit.mid: data byte must be in range 0..127
# Error reading clean_midi/Mariah Carey/Long Ago.mid:
# Error reading clean_midi/Mariah Carey/Forever.mid: data byte must be in range 0..127
# Error reading clean_midi/Camel/The Snow Goose.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Camel/The Snow Goose.mid: data byte must be in range 0..127
# Error reading clean_midi/Blondie/Dreaming.mid: MIDI file has a largest tick of 4312862115, it is likely corrupt
# Error reading clean_midi/Ryan Paris/La Dolce Vita.1.mid: data byte must be in range 0..127
# Error reading clean_midi/ABBA/One Of Us.mid: data byte must be in range 0..127
# Error reading clean_midi/ABBA/Voulez Vous.1.mid: data byte must be in range 0..127
# Error reading clean_midi/ABBA/I've Been Waiting For You.mid: data byte must be in range 0..127
# Error reading clean_midi/ABBA/Thank You for the Music.2.mid: data byte must be in range 0..127
# Error reading clean_midi/ABBA/Take a Chance on Me.3.mid: data byte must be in range 0..127
# Error reading clean_midi/John Elton/Nikita.2.mid: data byte must be in range 0..127
# Error reading clean_midi/a-ha/Take On Me.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Chic/Take My Love.mid: data byte must be in range 0..127
# Error reading clean_midi/Chic/Chic Mystique.mid: data byte must be in range 0..127
# Error reading clean_midi/U2/Where the Streets Have No Name.7.mid: data byte must be in range 0..127
# Error reading clean_midi/U2/Walk On.mid: MThd not found. Probably not a MIDI file
# Error reading clean_midi/Coolio/Gangsta's Paradise.3.mid: data byte must be in range 0..127
# Error reading clean_midi/Elton John/Nikita.mid: data byte must be in range 0..127
# Error reading clean_midi/Elton John/A Word in Spanish.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Jean Michel Jarre/Calypso, Part 2.mid: data byte must be in range 0..127
# Error reading clean_midi/The Cranberries/Promises.1.mid: MThd not found. Probably not a MIDI file
# Error reading clean_midi/The Cranberries/Animal Instinct.mid: data byte must be in range 0..127
# Error reading clean_midi/Nelly/Country Grammar (Hot ...).mid: data byte must be in range 0..127
# Error reading clean_midi/Robert Palmer/I'll Be Your Baby Tonight.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Robert Palmer/Mercy Mercy Me   I Want You.mid: data byte must be in range 0..127
# Error reading clean_midi/Survivor/Is This Love.mid: data byte must be in range 0..127
# Error reading clean_midi/Shakatak/Night Birds.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Pink Floyd/High Hopes.2.mid: data byte must be in range 0..127
# Error reading clean_midi/Pink Floyd/The Trial.1.mid:
# Error reading clean_midi/Pink Floyd/Echoes.mid: data byte must be in range 0..127
# Error reading clean_midi/Pink Floyd/Nobody Home.mid: data byte must be in range 0..127
# Error reading clean_midi/Pink Floyd/Hey You.mid: data byte must be in range 0..127
# Error reading clean_midi/Pink Floyd/Echoes.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Pink Floyd/Wish You Were Here.mid: data byte must be in range 0..127
# Error reading clean_midi/Jackson Michael/Don't Stop 'Til You Get Enough.mid: Message length 2093056 exceeds maximum length 1000000
# Error reading clean_midi/Jackson Michael/Thriller.3.mid: data byte must be in range 0..127
# Error reading clean_midi/Jackson Michael/I'll Be There.mid:
# Error reading clean_midi/Jackson Michael/Childhood.mid: Could not decode key with 5 flats and mode 2
# Error reading clean_midi/Jackson Michael/Smooth Criminal.mid: MThd not found. Probably not a MIDI file
# Error reading clean_midi/Jackson Michael/Smooth Criminal.4.mid: data byte must be in range 0..127
# Error reading clean_midi/Jackson Michael/You Are Not Alone.mid: data byte must be in range 0..127
# Error reading clean_midi/The Rolling Stones/The Last Time.mid:
# Error reading clean_midi/10cc/Dreadlock Holiday.4.mid: data byte must be in range 0..127
# Error reading clean_midi/Alice in Chains/Sludge Factory.mid:
# Error reading clean_midi/Theodorakis Mikis/Zorba's Dance.1.mid: Could not decode key with 11 sharps and mode 227
# Error reading clean_midi/Toto/I Won't Hold You Back.mid: Could not decode key with 3 flats and mode 255
# Error reading clean_midi/Bee Gees/Stayin Alive.3.mid: Message length 2093056 exceeds maximum length 1000000
# Error reading clean_midi/Bee Gees/How Can You Mend a Broken Heart.1.mid: MIDI file has a largest tick of 12884927490, it is likely corrupt
# Error reading clean_midi/Bee Gees/Too Much Heaven.mid: data byte must be in range 0..127
# Error reading clean_midi/Brian McKnight/On the Down Low.mid:
# Error reading clean_midi/Billy Swan/I Can Help.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Bryson/Tonight I Celebrate My Love For You.mid: data byte must be in range 0..127
# Error reading clean_midi/Kalua Beach Boys/There's No Place Like Hawaii.mid: Could not decode key with 1 flats and mode 255
# Error reading clean_midi/Amos, Tori/The Wrong Band.mid: Could not decode key with 5 flats and mode 255
# Error reading clean_midi/The Doors/The Crystal Ship.3.mid: data byte must be in range 0..127
# Error reading clean_midi/The Doors/Riders on the Storm.1.mid:
# Error reading clean_midi/Nomadi/Io vagabondo.4.mid: data byte must be in range 0..127
# Error reading clean_midi/Nomadi/Io vagabondo.2.mid: data byte must be in range 0..127
# Error reading clean_midi/Madonna/Deeper and Deeper.mid: Message length 2093056 exceeds maximum length 1000000
# Error reading clean_midi/Madonna/Like A Virgin.mid:
# Error reading clean_midi/Madonna/Rain.4.mid: Could not decode key with 2 flats and mode 255
# Error reading clean_midi/Wonder Stevie/Happy Birthday.mid: data byte must be in range 0..127
# Error reading clean_midi/Wonder Stevie/Sir Duke.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Sting/Fields of Gold.1.mid: MThd not found. Probably not a MIDI file
# Error reading clean_midi/Sting/Fields of Gold.7.mid: no MTrk header at start of track
# Error reading clean_midi/Darin Bobby/Splish Splash.mid: data byte must be in range 0..127
# Error reading clean_midi/The Offspring/No Hero.mid: MThd not found. Probably not a MIDI file
# Error reading clean_midi/The Offspring/Gone Away.1.mid: MIDI file has a largest tick of 196929468, it is likely corrupt
# Error reading clean_midi/Level 42/Lessons in Love.2.mid: data byte must be in range 0..127
# Error reading clean_midi/Parker Charlie/Donna Lee.mid: data byte must be in range 0..127
# Error reading clean_midi/Styx/Come Sail Away.4.mid: data byte must be in range 0..127
# Error reading clean_midi/Bryan Adams/(Everything I Do) I Do It For You.7.mid: MThd not found. Probably not a MIDI file
# Error reading clean_midi/Aaron Neville/Tell It Like It Is.mid: data byte must be in range 0..127
# Error reading clean_midi/Bon Jovi/Blaze of Glory.2.mid:
# Error reading clean_midi/Neil Diamond/(Encore) Cracklin' Rose.mid: Could not decode key with 2 flats and mode 2
# Error reading clean_midi/Neil Diamond/Hello Again.mid: data byte must be in range 0..127
# Error reading clean_midi/Stevens Shakin /You Drive Me Crazy.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Dalla/Anna e Marco.mid: data byte must be in range 0..127
# Error reading clean_midi/Enya/Bard Dance.mid: Could not decode key with 1 flats and mode 255
# Error reading clean_midi/Rascel/Arrividerci Roma.mid: data byte must be in range 0..127
# Error reading clean_midi/Emerson, Lake & Palmer/Hoedown.mid: data byte must be in range 0..127
# Error reading clean_midi/Emerson, Lake & Palmer/Fanfare for the Common Man.2.mid: data byte must be in range 0..127
# Error reading clean_midi/Garbage/Cherry Lips.mid:
# Error reading clean_midi/Garbage/Stupid Girl.3.mid:
# Error reading clean_midi/Energy 52/Cafe del Mar.mid: data byte must be in range 0..127
# Error reading clean_midi/4 Non Blondes/What's Up.5.mid: data byte must be in range 0..127
# Error reading clean_midi/Matt Bianco/Half a Minute.mid: data byte must be in range 0..127
# Error reading clean_midi/The Knack/My Sharona.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Led Zeppelin/In The Evening.mid: data byte must be in range 0..127
# Error reading clean_midi/Led Zeppelin/Custard Pie.mid: data byte must be in range 0..127
# Error reading clean_midi/Led Zeppelin/Stairway To Heaven.mid: data byte must be in range 0..127
# Error reading clean_midi/Yazz & plastic population/The Only Way Is Up.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Johnny Mercer/Come Rain or Come Shine.mid: data byte must be in range 0..127
# Error reading clean_midi/Nirvana/Son of a Gun.2.mid: no MTrk header at start of track
# Error reading clean_midi/Nirvana/Frances Farmer Will Have Her Revenge on Seattle.1.mid: running status without last_status
# Error reading clean_midi/Nirvana/Radio Friendly Unit Shifter.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Nirvana/(New Wave) Polly.mid: running status without last_status
# Error reading clean_midi/Nirvana/Dive.mid: data byte must be in range 0..127
# Error reading clean_midi/Nirvana/Love Buzz.mid: no MTrk header at start of track
# Error reading clean_midi/Nirvana/Pennyroyal Tea.2.mid: data byte must be in range 0..127
# Error reading clean_midi/Nirvana/Lounge Act.mid: data byte must be in range 0..127
# Error reading clean_midi/Nirvana/Negative Creep.mid: no MTrk header at start of track
# Error reading clean_midi/Nirvana/Hairspray Queen.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Nirvana/Mexican Seafood.mid: running status without last_status
# Error reading clean_midi/Nirvana/Mr. Moustache.mid: running status without last_status
# Error reading clean_midi/Nirvana/Heart-Shaped Box.mid: running status without last_status
# Error reading clean_midi/Nirvana/Been a Son.mid: running status without last_status
# Error reading clean_midi/Nirvana/Sliver.2.mid: data byte must be in range 0..127
# Error reading clean_midi/Nirvana/Smells Like Teen Spirit.8.mid: data byte must be in range 0..127
# Error reading clean_midi/Nirvana/Aneurysm.mid: data byte must be in range 0..127
# Error reading clean_midi/Nirvana/Territorial Pissings.mid: data byte must be in range 0..127
# Error reading clean_midi/Nirvana/Dumb.2.mid: data byte must be in range 0..127
# Error reading clean_midi/Nirvana/Swap Meet.mid: data byte must be in range 0..127
# Error reading clean_midi/Nirvana/Milk It.1.mid: running status without last_status
# Error reading clean_midi/Nirvana/Polly.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Nirvana/Drain You.mid: no MTrk header at start of track
# Error reading clean_midi/Nirvana/All Apologies.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Nirvana/tourette's.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Nirvana/Downer.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Nirvana/Turnaround.mid: data byte must be in range 0..127
# Error reading clean_midi/Nirvana/Scentless Apprentice.mid: data byte must be in range 0..127
# Error reading clean_midi/The Stylistics/I'm Stone in Love With You.mid: data byte must be in range 0..127
# Error reading clean_midi/Pooh/Il cielo e blu sopra le nuvole.mid: data byte must be in range 0..127
# Error reading clean_midi/Rammstein/Stripped.mid: Could not decode key with 1 flats and mode 255
# Error reading clean_midi/The Outhere Brothers/Don't Stop (Wiggle Wiggle).1.mid: data byte must be in range 0..127
# Error reading clean_midi/Jimi Hendrix/Purple Haze.2.mid: data byte must be in range 0..127
# Error reading clean_midi/Rossi Vasco/Vivere.mid: data byte must be in range 0..127
# Error reading clean_midi/Depeche Mode/Shake the Disease.mid: Could not decode key with 1 flats and mode 255
# Error reading clean_midi/Aqua/Dr Jones.mid: data byte must be in range 0..127
# Error reading clean_midi/Beastie Boys/Girls.mid: Could not decode key with 1 flats and mode 255
# Error reading clean_midi/Marc Anthony/Vivir Lo Nuestro.mid: data byte must be in range 0..127
# Error reading clean_midi/The Platters/Only You.5.mid: data byte must be in range 0..127
# Error reading clean_midi/R.E.M./Nightswimming.mid: MThd not found. Probably not a MIDI file
# Error reading clean_midi/Huey Lewis & The News/The Power of Love.mid: data byte must be in range 0..127
# Error reading clean_midi/Sam Cooke/Twisting the Night Away.mid: data byte must be in range 0..127
# Error reading clean_midi/The Police/Every Little Thing She Does Is Magic.4.mid: data byte must be in range 0..127
# Error reading clean_midi/The Police/So Lonely.1.mid: Message length 2093056 exceeds maximum length 1000000
# Error reading clean_midi/Roy Orbison/Oh Pretty Woman.2.mid: Could not decode key with 0 flats and mode 2
# Error reading clean_midi/Peter, Paul & Mary/Puff.1.mid: Could not decode key with 2 flats and mode 255
# Error reading clean_midi/Bernstein Leonard/West Side Story: Medley.1.mid: data byte must be in range 0..127
# Error reading clean_midi/The Four Seasons/Walk Like A Man.mid: data byte must be in range 0..127
# Error reading clean_midi/The Four Seasons/Rag Doll.mid: data byte must be in range 0..127
# Error reading clean_midi/Henry Mancini/Moon River.mid: Could not decode key with 12 sharps and mode 95
# Error reading clean_midi/Live/Selling the Drama.mid: data byte must be in range 0..127
# Error reading clean_midi/Steppenwolf/Born To Be Wild.3.mid: data byte must be in range 0..127
# Error reading clean_midi/The Smashing Pumpkins/Cherub Rock.mid: data byte must be in range 0..127
# Error reading clean_midi/Third Eye Blind/Semi-Charmed Life.mid: MThd not found. Probably not a MIDI file
# Error reading clean_midi/Third Eye Blind/Semi-Charmed Life.1.mid: MThd not found. Probably not a MIDI file
# Error reading clean_midi/LL Cool J/Hey Lover.mid: data byte must be in range 0..127
# Error reading clean_midi/Whigfield/Saturday Night.1.mid: data byte must be in range 0..127
# Error reading clean_midi/Morton Jelly Roll/Frog-I-More Rag.mid: data byte must be in range 0..127
# Error reading clean_midi/Tool/Flood.mid: MThd not found. Probably not a MIDI file
# Error reading clean_midi/Supertramp/Bloody Well Right.mid: data byte must be in range 0..127
# Error reading clean_midi/Supertramp/The Logical Song.7.mid:
# Error reading clean_midi/Sinatra/Where or When.mid: Could not decode key with 15 sharps and mode 66
# Error reading clean_midi/3T/Why.mid: data byte must be in range 0..127
# Error reading clean_midi/Pet Shop Boys/Always on My Mind   In My House.3.mid: undefined status byte 0xf5
# Error reading clean_midi/Daft Punk/Da Funk.mid: MThd not found. Probably not a MIDI file
# Error reading clean_midi/Rene Froger/Thunder in My Heart.mid: data byte must be in range 0..127
# Found 1953 good songs.

# %% [markdown]
# Above, we have utilized the $\texttt{Pretty\_MIDI}$ library and our custom function to extract the time signatures, tempo, and key of each song within our dataframe for 1000 songs.
#
# It is notable that we find that the $\texttt{Pretty\_MIDI}$ library actually interprets every song's tempo in double-time. This is found to be consistent and in line with other users of this library as well. Thus, we chose to divided the found tempo by two to ensure the correct single time metric.
#
# As the dataset is rather large and thus computationally expensive to run, we have randomly shuffled our data and selected to determine the distributions of the data based on the first 1000 songs of the dataset. By shuffling, we ensure that our data is able to be generalizable toward the greater dataset.
#
# From our Time Signature plot, we find that the vast majority of songs are in $\frac{4}{4}$ with a couple of outlier songs in other time signatures. Based on this plot, we will train a model to generate songs in $\frac{4}{4}$ timing as well.
#
# From our song distributions plot, we find an overwhelming range of song durations; this is most likely due to the variety of genres in the music the dataset. The median of song length seems to fall around the 4 minute mark, which makes sense considering the majority of our data consists of pop songs, which are generally between 3 to 5 minutes. We did not think of using this the duration until after we finishing milestone 3. We will incorporate the duration into our training from here onward.
#
# Analyzing the distribution of tempos, we find a bimodal graph normal distribution with peaks at the 90 BPM and 120 BPMmark, low points around the 60 BPM mark, and high points around the 140 BPM mark. This shows that the majority of our songs are more upbeat with faster tempos. This aligns with our finding that the majority of songs in this dataset are under the $\texttt{Pop}$ genre.
#
# Furthermore, we analyzed the number of notes played within each song. We sought to use this to infer the optimal length of each song. We notice a normal distribution with a mean peak at approximately 5000, with a lower bound of 100, and an upper bound of approximately 17,500 notes. Said distribution is found to be especially right-skewed past the 10,000 marking as well. While we were initially planning on using this data to infer the duration of the typical song, we soon realized that tempo, signature and other variables make this a poor indicator of duration. We need to pivot from this and find a better way to calculate the duration of each song with the end time stamp of each MIDI file. This will be utilized in the final model.
#
# Finally, for key signatures, we find that the vast majority of songs are in the key of $\texttt{C Major}$. This is in line with the fact that the majority of our songs are popsongs. When training our songs, we may choose to train our model specifically on songs in $\texttt{C Major}$ to ensure maximal accuracy.

# %% [markdown]
# Because we find the majority of the data within the dataset is $\texttt{Pop}$ music in $\texttt{C Major}$, and written in $\frac{4}{4}$ timing, we will pivot our goal to create the optimal $\text{Pop}$ Generative AI model, understanding that our given data is geared toward successfully creating said music from the dataset. Allow us now to extract the full dataset below.
#
# For now, we will train a baseline model with the first 100 entities within $\texttt{shuffled\_file\_names}$ contents as a baseline model.

# %% [markdown]
# **Baseline Model Creation**

# %%
# Create a custom function for tokenizing using music21
def tokenize_midi_music21(file_path):
    midi = converter.parse(file_path) # Extract score of MIDI file
    notes = [] # Store tokens
    
    # Iterate through all notes, chords, and rests in all parts
    for element in midi.recurse().notesAndRests:
        duration = round(element.quarterLength, 2) # For the sake of consistency

        # Found single pitch, format of 'Pitch_duration'
        if isinstance(element, note.Note):
            token = f"{element.pitch}_{duration}"
            notes.append(token)

        # Found chord, pitches separated by .
        elif isinstance(element, chord.Chord):
            pitches = ".".join(str(n) for n in element.normalOrder)
            token = f"{pitches}_{duration}"
            notes.append(token)

        # Found a rest
        elif isinstance(element, note.Rest):
            token = f"Rest_{duration}"
        
        else:
            continue

        notes.append(token)

    return notes

# %%
# Tokenize a single file
def tokenize(file_name):
    file_path = os.path.join("extracted_midi", file_name) # Find path
    try:
        tokens = tokenize_midi_music21(file_path) # Get tokens
        return tokens
    
    # Contingency failure
    except Exception as e:
        return None

# Tokenize in parallel
token_seqs = []
num_files = 100 # number of file to consider

# Paralle processing as per TF advice to speed up the tokenization time (By default uses all available cores
with ProcessPoolExecutor() as executor:
    # Submit tasks
    futures = [executor.submit(tokenize, file_name) for file_name in shuffled_file_names[:num_files]]

    # Gather results with progress bar
    for f in tqdm(as_completed(futures), total=len(futures), desc="Tokenizing MIDI"):
        result = f.result()
        if result:
            token_seqs.append(result)

# Combine all token sequences into a single flat list of tokens corpus
all_tokens = [token for seq in token_seqs for token in seq]

# Count the frequency of each occurrence
token_counts = Counter(all_tokens)

# Find the vocabulary
vocab = sorted(token_counts.keys())

# Map token to an index
token_to_idx = {tok: i for i, tok in enumerate(vocab)}

# Map index to a token 
idx_to_token = {i: tok for tok, i in token_to_idx.items()}

# Convert token sequences to index sequences
indexed_seqs = [[token_to_idx[tok] for tok in seq if tok in token_to_idx] for seq in token_seqs]
# Out:
# Tokenizing MIDI: 100%|██████████| 100/100 [00:15<00:00,  6.54it/s]

# %%
# Process data into sequences
def make_sequences(token_ids, seq_len=128, step=1):
    X, y = [], []
    for i in range(0, len(token_ids) - seq_len, step):
        X.append(token_ids[i:i+seq_len])
        y.append(token_ids[i+seq_len])
    return X, y

X_all, y_all = [], []
for seq in indexed_seqs:
    X_seq, y_seq = make_sequences(seq)
    X_all.extend(X_seq)
    y_all.extend(y_seq)

# Create X_all and y_all np arrays
X_all = np.array(X_all)
y_all = np.array(y_all)

# Create tensorflow pipeline to convert to dataset
X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.2, random_state=109)

# Slice, shuffle, and batch data
def pipeline(x,y):
    dataset = tf.data.Dataset.from_tensor_slices((x,y))
    dataset = dataset.shuffle(buffer_size=y.shape[0])
    dataset = dataset.batch(batch_size=64)
    return dataset

#dataset = pipeline(X_train,y_train)

# %% [markdown]
# For our baseline model, we built a simple Recurrent Neural Network (RNN) using Keras. RNNs are advantageous for sequence modeling tasks, like music generation. We designed the model with an Embedding layer that transforms the tokens in vector representations, then a Gated Recurrent Unit (GRU) layer that processes the sequential data, then a final Dense layer that uses the softmax activation function to output a probability distribution of 409 possible classes.

# %%
# Create baseline model with a Vanilla RNN with GRU
MAX_VOCAB = len(token_to_idx)
EMBED_DIM = 64

model = Sequential(name = "baseline_rnn")
model.add(Embedding(MAX_VOCAB, EMBED_DIM, input_length=128))
model.add(GRU(64))
model.add(Dense(MAX_VOCAB, activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.build(input_shape=(None,128))
print(model.summary())

# %%
# history = model.fit(dataset, epochs=30, batch_size=64,verbose =1)
# model.save_weights('model/rnn_1_model')
dataset = pipeline(X_train,y_train)
test_dataset = pipeline(X_test, y_test)
history = model.fit(dataset, epochs=30, batch_size=64, verbose=1, validation_data=test_dataset)

# %% [markdown]
# Understanding that our baseline model only utilized the first 100 midi files of $\texttt{shuffled\_file\_names}$, is currently a vanilla iteration of GRU, and that we have yet to filter our data to ensure optimal image generation, we find that our accuracy of 0.7465 is more than sufficient and pleasing to us for a baseline model. From this point, we seek to generate a song to see what our results are like for fun :)

# %%
# Accuracy plot
epochs = list(range(1, len(history.history['accuracy']) + 1))
plt.plot(epochs,history.history['accuracy'], label='Train Accuracy')
plt.plot(epochs,history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Baseline Model: Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.xticks(epochs) 
plt.grid(True)
plt.show()

# Loss plot
plt.plot(epochs,history.history['loss'], label='Train Loss')
plt.plot(epochs,history.history['val_loss'], label='Validation Loss')
plt.title('Baseline Model: Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.xticks(epochs) 
plt.grid(True)
plt.show()

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Bidirectional, GRU, Dense, Dropout, BatchNormalization, Attention, Concatenate
from tensorflow.keras.layers import GlobalAveragePooling1D

MAX_VOCAB = len(token_to_idx)
EMBED_DIM = 128
SEQ_LEN = 128

# Input layer
inputs = Input(shape=(SEQ_LEN,), name="input_tokens")

# Embedding
x = Embedding(input_dim=MAX_VOCAB, output_dim=EMBED_DIM, input_length=SEQ_LEN)(inputs)

# GRU stack
x = Bidirectional(GRU(128, return_sequences=True))(x)  # 1st layer
x = Bidirectional(GRU(128, return_sequences=True))(x)  # 2nd layer
x = Bidirectional(GRU(128, return_sequences=True))(x)  # 3rd layer (added)

# Attention block
attention_output = Attention(name="attention_layer")([x, x])  # self-attention
x = Concatenate()([x, attention_output])
x = GlobalAveragePooling1D()(x)

# Deeper dense tower
x = Dense(256, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)

# Final output
x = Dense(MAX_VOCAB, activation='softmax')(x)

# Build and compile model
model = Model(inputs=inputs, outputs=x, name="deep_gru_with_attention")
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# 2025-05-09 14:39:36.467017: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-09 14:39:36.528050: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-09 14:39:36.531693: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-09 14:39:36.536170: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-09 14:39:36.539732: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-09 14:39:36.543086: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-09 14:39:36.681686: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-09 14:39:36.683391: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-09 14:39:36.685093: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-09 14:39:36.686675: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20723 MB memory:  -> device: 0, name: NVIDIA A10G, pci bus id: 0000:00:1e.0, compute capability: 8.6
# Model: "deep_gru_with_attention"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_tokens (InputLayer)   [(None, 128)]                0         []
#
#  embedding (Embedding)       (None, 128, 128)             666112    ['input_tokens[0][0]']
#
#  bidirectional (Bidirection  (None, 128, 256)             198144    ['embedding[0][0]']
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 128, 256)             296448    ['bidirectional[0][0]']
#  onal)
#
#  bidirectional_2 (Bidirecti  (None, 128, 256)             296448    ['bidirectional_1[0][0]']
#  onal)
#
#  attention_layer (Attention  (None, 128, 256)             0         ['bidirectional_2[0][0]',
#  )                                                                   'bidirectional_2[0][0]']
#
#  concatenate (Concatenate)   (None, 128, 512)             0         ['bidirectional_2[0][0]',
#                                                                      'attention_layer[0][0]']
#
#  global_average_pooling1d (  (None, 512)                  0         ['concatenate[0][0]']
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 256)                  131328    ['global_average_pooling1d[0][
#                                                                     0]']
#
#  dropout (Dropout)           (None, 256)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  32896     ['dropout[0][0]']
#
#  batch_normalization (Batch  (None, 128)                  512       ['dense_1[0][0]']
#  Normalization)
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['batch_normalization[0][0]']
#
#  dense_2 (Dense)             (None, 5204)                 671316    ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 2293204 (8.75 MB)
# Trainable params: 2292948 (8.75 MB)
# Non-trainable params: 256 (1.00 KB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

lr_schedule = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

dataset = pipeline(X_train,y_train)
test_dataset = pipeline(X_test, y_test)
model.fit(dataset,
    validation_data=test_dataset,
    epochs=50,
    batch_size=64,
    callbacks=[lr_schedule, early_stop]
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1746816006.808352   27664 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA A10G" frequency: 1710 num_cores: 80 environment { key: "architecture" value: "8.6" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 6291456 shared_memory_size_per_multiprocessor: 102400 memory_size: 21730033664 bandwidth: 600096000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2025-05-09 14:40:07.742943: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2025-05-09 14:40:08.998199: I external/local_xla/xla/service/service.cc:168] XLA service 0x149ccc14a430 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-05-09 14:40:08.998255: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A10G, Compute Capability 8.6
# 2025-05-09 14:40:09.003538: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1746816009.105556   30763 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 6949/6949 [==============================] - ETA: 0s - loss: 3.5977 - accuracy: 0.3991
# W0000 00:00:1746816226.218922   27664 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA A10G" frequency: 1710 num_cores: 80 environment { key: "architecture" value: "8.6" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 6291456 shared_memory_size_per_multiprocessor: 102400 memory_size: 21730033664 bandwidth: 600096000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 6949/6949 [==============================] - 244s 34ms/step - loss: 3.5977 - accuracy: 0.3991 - val_loss: 2.4233 - val_accuracy: 0.5672 - lr: 0.0010
# Epoch 2/50
# 6949/6949 [==============================] - 210s 30ms/step - loss: 2.3785 - accuracy: 0.5730 - val_loss: 2.0823 - val_accuracy: 0.6244 - lr: 0.0010
# Epoch 3/50
# 6949/6949 [==============================] - 209s 30ms/step - loss: 2.1113 - accuracy: 0.6143 - val_loss: 1.9296 - val_accuracy: 0.6480 - lr: 0.0010
# Epoch 4/50
# 6949/6949 [==============================] - 209s 30ms/step - loss: 1.9570 - accuracy: 0.6366 - val_loss: 1.8294 - val_accuracy: 0.6656 - lr: 0.0010
# Epoch 5/50
# 6949/6949 [==============================] - 209s 30ms/step - loss: 1.8465 - accuracy: 0.6541 - val_loss: 1.7613 - val_accuracy: 0.6769 - lr: 0.0010
# Epoch 6/50
# 6949/6949 [==============================] - 209s 30ms/step - loss: 1.7684 - accuracy: 0.6658 - val_loss: 1.7442 - val_accuracy: 0.6826 - lr: 0.0010
# Epoch 7/50
# 6949/6949 [==============================] - 209s 30ms/step - loss: 1.7078 - accuracy: 0.6742 - val_loss: 1.6946 - val_accuracy: 0.6892 - lr: 0.0010
# Epoch 8/50
# 6949/6949 [==============================] - 209s 30ms/step - loss: 1.6626 - accuracy: 0.6812 - val_loss: 1.6663 - val_accuracy: 0.6965 - lr: 0.0010
# Epoch 9/50
# 6581/6949 [===========================>..] - ETA: 10s - loss: 1.6271 - accuracy: 0.6863

# %%
# Accuracy plot
epochs = list(range(1, len(history.history['accuracy']) + 1))
plt.plot(epochs,history.history['accuracy'], label='Train Accuracy')
plt.plot(epochs,history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Second Model: Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.xticks(epochs) 
plt.grid(True)
plt.show()

# Loss plot
plt.plot(epochs,history.history['loss'], label='Train Loss')
plt.plot(epochs,history.history['val_loss'], label='Validation Loss')
plt.title('Second Model: Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.xticks(epochs) 
plt.grid(True)
plt.show()

# %%
from music21 import stream, note, chord
import numpy as np
import random

# Convert token id to music 21 streams
def decode_to_music21(token_ids, idx_to_token):

    output = stream.Stream() # Initialize a music21 stream to hold the result

    # Iterate through each token ID in the generated sequence
    for tok_id in token_ids:
        token = idx_to_token[tok_id]
        # Derive out all our tokens based on the formula we established for it earlier
        try:
            pitch_info, dur = token.split("_") # Split pitch and duration information
            dur = float(dur)

            # Chord Event Case
            if "." in pitch_info:
                pitches = [int(p) for p in pitch_info.split(".")]
                c = chord.Chord(pitches)
                c.quarterLength = dur
                output.append(c)

            # Single note event case 
            else:
                n = note.Note(pitch_info)
                n.quarterLength = dur
                output.append(n)
        except:
            continue # Contingency plan of just skipping
            
    return output

# Custom function to generate music
def generate_music(model, idx_to_token, seed_seq, max_tokens=200, temperature=1.0):
    generated = seed_seq.copy()
    current_seq = seed_seq[-128:] # Establish a window of 128

    # Iterate through
    for _ in range(max_tokens):
        # Pad or truncate input to length 128
        input_seq = current_seq[-128:]
        input_seq = np.array(input_seq).reshape(1, -1)

        # Predict the next token distribution
        preds = model.predict(input_seq, verbose=0)[0]

        # Apply temperature
        preds = np.log(preds + 1e-9) / temperature
        preds = np.exp(preds) / np.sum(np.exp(preds))

        # Sample from the distribution
        next_token = np.random.choice(len(preds), p=preds)
        generated.append(next_token)
        current_seq.append(next_token)

    return decode_to_music21(generated, idx_to_token)

# %%
# Pick a seed and generate music
seed = X_test[random.randint(0, len(X_test)-1)].tolist()
generated_stream = generate_music(model, idx_to_token, seed, max_tokens=200, temperature=1.0)

# %%
from IPython.display import Audio
import tempfile
import pretty_midi

# Save to a temporary MIDI file
with tempfile.NamedTemporaryFile(suffix=".mid", delete=False) as tmp:
    midi_path = tmp.name
    generated_stream.write('midi', fp=midi_path)

# Convert MIDI to audio using pretty_midi
midi_data = pretty_midi.PrettyMIDI(midi_path)
audio_waveform = midi_data.synthesize()

# Audio!!!!!!!
Audio(audio_waveform, rate=44100)

# %% [markdown]
# '''
# To-Do
# - Build final model and show results
#
# MS4 Guidelines
#
# 1. Problem Statement Refinement and introduction:
# Develop an introduction to your project.
#
# Reiterate/refine your problem statement if needed. Ensure it is clear and understandable to someone outside your field.
#
# Articulate significance based on new insights from EDA, highlighting shifts in perspective or understanding.
#
# 2. Comprehensive EDA Review:
# Include key findings from your EDA paper, focusing on how these insights informed feature engineering and model selection.
#
# Detail the feature engineering process, including transformations, encoding, or selection techniques, with justifications rooted in EDA.
#
# Include visualizations that support analytical decisions, linking back to the problem statement and project goals.
#
# 3. Baseline Model Selection and Justification:
# Explain the choice of your baseline model, considering simplicity, interpretability, and relevance.
#
# Detail the training process, including preprocessing, parameters, and metrics used for evaluation.
#
# Present initial results, discussing alignment with expectations and project objectives.
#
# 4. Results Interpretation and Analysis:
# Analyze the baseline model’s performance, using appropriate metrics and visualizations.
#
# Assess strengths and weaknesses of the model, proposing improvements for the next iteration.
#
# 5. Final Model Pipeline Setup:
# Outline steps for a pipeline for your final model, describing each component from data preprocessing to evaluation.
#
# Document assumptions, parameter choices, and preliminary tuning considerations.
#
# Effective Notebook Submission Guidelines:
# Start with a clear, concise problem statement.
#
# Organize logically with headings and subheadings; table of contents are required!
#
# Explain code, choices, and results using comments and markdown.
#
# Use clear, well-labeled visualizations with descriptive captions.
#
# Maintain clean, readable code with structured processes.
#
# Ensure reproducibility if needed: the notebook should run error and warning-free and document data sources.
#
# Deliverables:
# Submit a well-organized .ipynb notebook by the due date above. Focus on clarity and depth in your documentation, linking EDA insights to your new baseline model choices.
# '''

# %% [markdown]
# After hearing the song above, we are extraordinarily happy with the output of this audio. Said song gives upbeat pop MineCraft-type music. From this point forward.
